# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("P1-RegresionLineal.csv")

# %%
df=pd.DataFrame(data)
plt.plot(df['equipos'],df['costo'],"b.")
plt.xlabel("Equipos Afectados")
plt.ylabel("costo del incidente")
plt.show()
a = 0

# %%
 # Variable de control

if a == 0:  # Solo se ejecuta si 'a' es 0
    data['equipos'] = data['equipos'] * 1000
    data['equipos'] = data['equipos'].astype('int')
    data['costo'] = data['costo'] * 10000
    data['costo'] = data['costo'].astype('int')
    a = 1  # Actualiza 'a' para evitar la multiplicación de nuevo

# Para ver los primeros 10 registros
data.head(10)
# Out:
#    Unnamed: 0  equipos  costo
# 0           0      921  72723
# 1           1      389  47653
# 2           2      628  42289
# 3           3     1178  86954
# 4           4     1088  74786
# 5           5      766  61929
# 6           6       95  54459
# 7           7     1037  72210
# 8           8      184  40889
# 9           9     1801  91531

# %%
plt.plot(data['equipos'],data['costo'],"b.")
plt.xlabel("Equipos Afectados")
plt.ylabel("costo del incidente")
plt.show()

# %%
lin_reg=LinearRegression()
lin_reg.fit(df['equipos'].values.reshape(-1,1), df['costo'].values)
# Out:
# LinearRegression()

# %%
theta1=lin_reg.coef_[0]
print(f"theta1= {theta1}")
# Out:
# theta1= 3.047794691382995

# %%
x_min_max=np.array([[df["equipos"].min()],[df["equipos"].max()]])
y_train_pred= lin_reg.predict(x_min_max)

plt.plot(x_min_max,y_train_pred,"g-")
plt.plot(df['equipos'],df['costo'],"b.")
plt.xlabel("equipos afectados")
plt.ylabel("Coste del incidente")
plt.show()

# %%
datap = pd.read_csv("micsv.csv")
df1=pd.DataFrame(datap)

# %%
df1['equipos']=df1['equipos']*1000
df1['equipos']=df1['equipos'].astype('int')
predicciones=lin_reg.predict(df1)
for i in range(len(df1)):
    plt.plot(df1.iloc[i,0], predicciones[i],'rx')

plt.plot(df1['equipos'], predicciones, color='blue', label='Predicciones', linewidth=1)
plt.title('Predicciones de Regresión Lineal')
plt.xlabel('equipos')
plt.ylabel('costo')
plt.legend()
plt.show()
# Out:
# c:\Users\joses\anaconda3\envs\ia2clase\Lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
